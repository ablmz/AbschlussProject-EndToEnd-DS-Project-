# %% [markdown]
# ## Prozess 1: Web Scraping
#
# Aufgabe: Beziehen von Rezensionen von den Seiten Klinikbewertungen.de & Google Maps
# Umfang: Rezensionen von mindestens 15 Kliniken beziehen (Liste der verfügbaren Kliniken auf Moodle, Dokument: Klinikliste)
# Rahmen Google:
# -	Pflicht: Name der Klinik, Textuelle Bewertung, Sternebewertung, Datum der Bewertung, Likes
# -	Optional: Antwort, Datum der Antwort, Nutzerinformationen (Local Guide, Rezensionsanzahl)
# -	Nicht: Nutzername 🡪 Bezug möglich, aber nicht auf Webseite anzeigen
# Rahmen Klinikbewertungen:
# -	Pflicht: Name der Klinik, Titel, Datum der Bewertung, Fachbereich, Sternebewertung (Gesamtzufriedenheit, Qualität der Beratung, Mediz. Behandlung, Verwaltung und Abläufe, Ausstattung und Gestaltung), Erfahrungsbericht
# -	Optional: Behandlungsjahr, Berichtender, Daumen hoch/runter, Textuelle Sternebewertungen, Pro, Kontra, Krankheitsbild, Privatpatient, Kommentare
# -	Nicht: Nutzername 🡪 Bezug möglich, aber nicht auf Webseite anzeigen
# -	Hinweis: Bei Klinikbewertungen gibt es Bewertungen, die nicht in die Gesamtbewertungen mit einfließen (auf der Webseite und innerhalb des HTML-Dokumentes gekennzeichnet). Entscheidet selbst, ob ihr diese Bewertungen mit einbeziehen wollt
# Ziel: Zwei Dateien mit den jeweiligen Bewertungen von Google Maps & Klinikbewertungen zur Weiterverarbeitung

# %% [markdown]
# ### Import Pandas und Konvertieren von Excel-Daten in Pandas DataFrame

# %%
import pandas as pd

data = pd.read_excel(r'C:\Users\name\Desktop\WB\Abschlussproject\Klinikliste.xlsx') # can also index sheet by name or fetch all sheets
df = pd.DataFrame(data, columns= ['Klinikname','Link Google Maps','Link Klinikbewertungen'])

# %%
df
# Out:
#                                   Klinikname  \
# 0                    Augenklinik Dr.Hoffmann
# 1       Krankenhaus Marienstift Braunschweig
# 2   Herzogin Elisabeth Hospital Braunschweig
# 3           Asklepios Fachklinikum Göttingen
# 4         Asklepios Fachklinikum Tiefenbrunn
# 5                  Friederikenstift Hannover
# 6                         Annastift Hannover
# 7                            Clementinenhaus
# 8                     Sophienklinik Hannover
# 9                 KRH Klinikum Großburgwedel
# 10                       KRH Klinikum Lehrte
# 11                   Krankenhaus Lindenbrunn
# 12                        Krankenhaus Hameln
# 13                     AMEOS Klinikum Alfeld
# 14                Helios Klinikum Hildesheim
# 15        AGAPLESION EV. KLINIKUM SCHAUMBURG
# 16                  Helios Klinikum Cuxhaven
# 17                OsteMed Klinik Bremervörde
# 18                     Klinik Fallingborstel
# 19                            Klinikum Emden
# ...

# %%
df.shape[0]
# Out:
# 24

# %% [markdown]
# ### Import Scrapy und Request

# %%
import requests
from scrapy.http import TextResponse

# %% [markdown]
# ### Überschriften der Textuelle Bewertung

# %%
titel=[]
def extracttitel():
    for i in range (df.shape[0]):
        url = df.iloc[i,2]
        r = requests.get(url)
        response = TextResponse(r.url,body=r.text,encoding="utf-8")
        #print(response)
        titel.append(response.xpath("//div[@class='list ratinglist']/article/header/h2/text()").extract())
    return titel

# %%
extracttitel()
# Out:
# [['Ich war sehr zufrieden mit allem',
#   'Endlich wieder klare Sicht',
#   'Beste Augenklinik',
#   'ich war ringsherum zufrieden',
#   'Akute und wiederholte Netzhautoperation',
#   'Perfekte Klinik fÃ¼r Augenerkrankte!',
#   'Hohe Kompetenz und Freundlichkeit!!',
#   'Gute Behandlung',
#   'Nette Arzthelferinnen, unangenehme Ã\x84rztinnen',
#   'Genervte Mitarbeiter in der Anmeldung',
#   'Immer wieder!',
#   'OP      B ereich freundlich und zuvorkommend',
#   'Inkompetente Beratung',
#   'Hut ab!',
#   'unzumutbare Wartezeiten',
#   'Patienten und Probleme sind lÃ¤stige BremsklÃ¶tze',
#   'Nie wieder.',
#   'SCHLIMMER GEHT IMMER !!!!',
#   'provessionelle und super Behandlung in der Klinik',
#   'Gute Augenklinik',
#   '100 % sehfÃ¤hig!',
#   'kommt darauf an, was man hat und wer einen behandelt...'],
#  ['Arzt und Schwestern waren eine Zumutung',
#   'Geburt sek.  Sectio',
#   'Beispielhaft in Niedersachsen',
#   'Kompetentes nettes Entbindungsteam',
#   'Sehr zufrieden',
# ...

# %% [markdown]
# ### Datum der Bewertung

# %%
time=[]
def extracttime():
    for i in range (df.shape[0]):
        url = df.iloc[i,2]
        r = requests.get(url)
        response = TextResponse(r.url,body=r.text,encoding="utf-8")
        #print(response)
        time.append(response.xpath("//div[@class='meta']/time/text()").extract())
    return time

# %%
extracttime()
# Out:
# [['20.01.2021',
#   '16.11.2020',
#   '22.03.2020',
#   '14.11.2019',
#   '11.11.2019',
#   '30.07.2019',
#   '23.07.2019',
#   '08.01.2019',
#   '31.10.2018',
#   '28.01.2018',
#   '31.10.2017',
#   '04.08.2017',
#   '28.07.2017',
#   '23.04.2017',
#   '08.11.2016',
#   '12.07.2016',
#   '21.04.2016',
#   '17.03.2016',
#   '08.11.2015',
#   '21.06.2015',
#   '13.04.2015',
#   '29.01.2015'],
#  ['19.09.2020',
#   '21.07.2020',
#   '23.03.2020',
#   '02.08.2019',
#   '29.07.2019',
#   '06.07.2019',
#   '10.04.2019',
#   '04.04.2019',
#   '28.03.2019',
#   '27.03.2019',
#   '10.08.2018',
#   '24.04.2018',
#   '12.04.2018',
#   '14.02.2018',
#   '09.01.2018',
#   '21.10.2017',
#   '29.08.2017',
#   '25.03.2017',
#   '24.03.2017',
#   '01.03.2017',
#   '28.02.2017',
#   '22.02.2017',
#   '15.01.2017',
#   '11.12.2016',
#   '15.11.2016',
#   '06.11.2016',
#   '04.10.2016',
#   '25.09.2016',
#   '07.09.2016',
#   '07.08.2016',
#   '18.06.2016',
#   '15.05.2016',
#   '07.03.2016',
# ...

# %% [markdown]
# ### Textuelle Bewertung

# %%
bewertungen=[]
def extractbewertungen():
    for i in range (df.shape[0]):
        url = df.iloc[i,2]
        r = requests.get(url)
        response = TextResponse(r.url,body=r.text,encoding="utf-8")
        #print(response)
        bewertungen.append(response.xpath("//p[@itemprop='reviewBody']/text()").extract())
    return bewertungen

# %%
extractbewertungen()
# Out:
# [['Bin sehr zufrieden gewesen mit der Klinik und dem Personal. Die erste OP verlief sehr gut +die  zweite folgt in 3 Wochen. Werde die Klinik auf jeden Fall weiterempfehlen',
#   'Komptentes Ã\x84rzteteam.',
#   '\nStrickte Einhaltung der Corona Schutzregeln.',
#   '\nRundum zufrieden',
#   'Ich komme seit einen halben Jahr mit meiner behinderten Frau hier zum Augen-Spritzen auf Grund eines diabetischen Makulasyndroms. Ich kann bis jetzt nur positiv berichten - auch wenn das Wartezimmer sehr voll ist - waren wir immer sehr schnell dran und innerhalb einer Stunde fertig. Hier wird der Patient noch als Mensch betrachtet und nicht als Nummer, es wird mit Namen aufgerufen - Kinder mit Vornamen. Bei Behinderungen werden die Patienten von den immer netten Schwestern betreut und es wird geholfen. Von den Ã\x84rzten bekommt man alles genau erklÃ¤rt - hier fÃ¼hlt man sich in guten HÃ¤nden - Danke an das gesamte Ã\x84rzte und Schwesternteam.',
# ...

# %% [markdown]
# ### Fachbereich

# %%
bereich=[]
def extractfachbereich():
    for i in range (df.shape[0]):
        url = df.iloc[i,2]
        r = requests.get(url)
        response = TextResponse(r.url,body=r.text,encoding="utf-8")
        bereich.append(response.xpath("//div[@class='list ratinglist']/article/span/a/text()").extract())
    return bereich

# %%
extractfachbereich()
# Out:
# [['Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen',
#   'Augen'],
#  ['Entbindung',
#   'Entbindung',
#   'Entbindung',
#   'Frauen',
#   'Chirurgie',
#   'Chirurgie',
#   'Urologie',
#   'Entbindung',
#   'Entbindung',
#   'Handchirurgie',
#   'Hals-Nasen-Ohren',
#   'Hals-Nasen-Ohren',
#   'Entbindung',
#   'Handchirurgie',
#   'Chirurgie',
#   'Frauen',
#   'Frauen',
#   'Frauen',
#   'Frauen',
#   'Frauen',
#   'Frauen',
#   'Entbindung',
#   'Frauen',
#   'Entbindung',
#   'Frauen',
#   'Handchirurgie',
#   'Frauen',
#   'Entbindung',
#   'Chirurgie',
#   'Frauen',
#   'Frauen',
#   'Entbindung',
#   'Frauen',
#   'Frauen',
#   'Chirurgie',
#   'Entbindung',
#   'Entbindung'],
#  ['Chirurgie',
#   'Chirurgie',
#   'Chirurgie',
#   'OrthopÃ¤die',
#   'Chirurgie',
# ...

# %% [markdown]
# ### Sterne Bewertung

# %%
sterne=[]
def extractsterne():
    for i in range (df.shape[0]):
        url = df.iloc[i,2]
        r = requests.get(url)
        response = TextResponse(r.url,body=r.text,encoding="utf-8")
        sterne.append(response.xpath("//div[@class='list ratinglist']/article/section[@class='rating']/dl/dd/img/text()").extract())
    return sterne

# %%
extractsterne()
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]
